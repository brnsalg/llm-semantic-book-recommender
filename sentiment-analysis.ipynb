# %%
import pandas as pd

books = pd.read_csv("books_with_categories.csv")

# %%
from transformers import pipeline
classifier = pipeline("text-classification",
                      model="j-hartmann/emotion-english-distilroberta-base",
                      top_k = None,
                      device = "mps")
classifier("I love this!")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# [[{'label': 'joy', 'score': 0.9771687984466553},
#   {'label': 'surprise', 'score': 0.008528684265911579},
#   {'label': 'neutral', 'score': 0.005764600355178118},
#   {'label': 'anger', 'score': 0.004419785924255848},
#   {'label': 'sadness', 'score': 0.0020923931151628494},
#   {'label': 'disgust', 'score': 0.0016119939973577857},
#   {'label': 'fear', 'score': 0.0004138521908316761}]]

# %%
books["description"][0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.'

# %%
classifier(books["description"][0])
# Out:
# [[{'label': 'fear', 'score': 0.6548407673835754},
#   {'label': 'neutral', 'score': 0.1698521375656128},
#   {'label': 'sadness', 'score': 0.11640916764736176},
#   {'label': 'surprise', 'score': 0.02070070058107376},
#   {'label': 'disgust', 'score': 0.019100762903690338},
#   {'label': 'joy', 'score': 0.015161278657615185},
#   {'label': 'anger', 'score': 0.003935154993087053}]]

# %%
classifier(books["description"][0].split("."))
# Out:
# [[{'label': 'surprise', 'score': 0.7296028733253479},
#   {'label': 'neutral', 'score': 0.14038564264774323},
#   {'label': 'fear', 'score': 0.06816212087869644},
#   {'label': 'joy', 'score': 0.0479423888027668},
#   {'label': 'anger', 'score': 0.009156350046396255},
#   {'label': 'disgust', 'score': 0.002628474496304989},
#   {'label': 'sadness', 'score': 0.0021221598144620657}],
#  [{'label': 'neutral', 'score': 0.4493715763092041},
#   {'label': 'disgust', 'score': 0.273591011762619},
#   {'label': 'joy', 'score': 0.10908259451389313},
#   {'label': 'sadness', 'score': 0.09362727403640747},
#   {'label': 'anger', 'score': 0.04047827422618866},
#   {'label': 'surprise', 'score': 0.026970207691192627},
#   {'label': 'fear', 'score': 0.006879073567688465}],
#  [{'label': 'neutral', 'score': 0.6462168097496033},
#   {'label': 'sadness', 'score': 0.24273258447647095},
#   {'label': 'disgust', 'score': 0.04342257231473923},
#   {'label': 'surprise', 'score': 0.02830050140619278},
#   {'label': 'joy', 'score': 0.014211480505764484},
#   {'label': 'fear', 'score': 0.014084085822105408},
#   {'label': 'anger', 'score': 0.011031880043447018}],
#  [{'label': 'fear', 'score': 0.9281691312789917},
#   {'label': 'anger', 'score': 0.032190266996622086},
#   {'label': 'neutral', 'score': 0.012808579951524734},
#   {'label': 'sadness', 'score': 0.008756828494369984},
#   {'label': 'surprise', 'score': 0.008597834967076778},
#   {'label': 'disgust', 'score': 0.008431742899119854},
#   {'label': 'joy', 'score': 0.0010455762967467308}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104149468243122},
#   {'label': 'disgust', 'score': 0.00648059556260705},
#   {'label': 'fear', 'score': 0.005393995437771082},
#   {'label': 'surprise', 'score': 0.0022869398817420006},
#   {'label': 'anger', 'score': 0.0018428885377943516},
#   {'label': 'joy', 'score': 0.0017338780453428626}],
#  [{'label': 'joy', 'score': 0.9327981472015381},
#   {'label': 'disgust', 'score': 0.03771703690290451},
#   {'label': 'neutral', 'score': 0.01589183323085308},
#   {'label': 'sadness', 'score': 0.006444488186389208},
#   {'label': 'anger', 'score': 0.005024972837418318},
#   {'label': 'surprise', 'score': 0.00158120587002486},
#   {'label': 'fear', 'score': 0.0005423062248155475}],
#  [{'label': 'joy', 'score': 0.6528705954551697},
#   {'label': 'neutral', 'score': 0.2542745769023895},
#   {'label': 'surprise', 'score': 0.06808319687843323},
#   {'label': 'sadness', 'score': 0.009909011423587799},
#   {'label': 'disgust', 'score': 0.006512208376079798},
#   {'label': 'anger', 'score': 0.004821314476430416},
#   {'label': 'fear', 'score': 0.003529018023982644}],
#  [{'label': 'neutral', 'score': 0.5494769811630249},
#   {'label': 'sadness', 'score': 0.11169016361236572},
#   {'label': 'disgust', 'score': 0.10400663316249847},
#   {'label': 'surprise', 'score': 0.07876548171043396},
#   {'label': 'anger', 'score': 0.06413359194993973},
#   {'label': 'fear', 'score': 0.0513627715408802},
#   {'label': 'joy', 'score': 0.0405643954873085}]]

# %%
sentences = books["description"][0].split(".")
predictions = classifier(sentences)

# %%
sentences[0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives'

# %%
predictions[0]
# Out:
# [{'label': 'surprise', 'score': 0.7296028733253479},
#  {'label': 'neutral', 'score': 0.14038564264774323},
#  {'label': 'fear', 'score': 0.06816212087869644},
#  {'label': 'joy', 'score': 0.0479423888027668},
#  {'label': 'anger', 'score': 0.009156350046396255},
#  {'label': 'disgust', 'score': 0.002628474496304989},
#  {'label': 'sadness', 'score': 0.0021221598144620657}]

# %%
sentences[3]
# Out:
# ' Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist'

# %%
predictions[3]
# Out:
# [{'label': 'fear', 'score': 0.9281691312789917},
#  {'label': 'anger', 'score': 0.032190266996622086},
#  {'label': 'neutral', 'score': 0.012808579951524734},
#  {'label': 'sadness', 'score': 0.008756828494369984},
#  {'label': 'surprise', 'score': 0.008597834967076778},
#  {'label': 'disgust', 'score': 0.008431742899119854},
#  {'label': 'joy', 'score': 0.0010455762967467308}]

# %%
predictions
# Out:
# [[{'label': 'surprise', 'score': 0.7296028733253479},
#   {'label': 'neutral', 'score': 0.14038564264774323},
#   {'label': 'fear', 'score': 0.06816212087869644},
#   {'label': 'joy', 'score': 0.0479423888027668},
#   {'label': 'anger', 'score': 0.009156350046396255},
#   {'label': 'disgust', 'score': 0.002628474496304989},
#   {'label': 'sadness', 'score': 0.0021221598144620657}],
#  [{'label': 'neutral', 'score': 0.4493715763092041},
#   {'label': 'disgust', 'score': 0.273591011762619},
#   {'label': 'joy', 'score': 0.10908259451389313},
#   {'label': 'sadness', 'score': 0.09362727403640747},
#   {'label': 'anger', 'score': 0.04047827422618866},
#   {'label': 'surprise', 'score': 0.026970207691192627},
#   {'label': 'fear', 'score': 0.006879073567688465}],
#  [{'label': 'neutral', 'score': 0.6462168097496033},
#   {'label': 'sadness', 'score': 0.24273258447647095},
#   {'label': 'disgust', 'score': 0.04342257231473923},
#   {'label': 'surprise', 'score': 0.02830050140619278},
#   {'label': 'joy', 'score': 0.014211480505764484},
#   {'label': 'fear', 'score': 0.014084085822105408},
#   {'label': 'anger', 'score': 0.011031880043447018}],
#  [{'label': 'fear', 'score': 0.9281691312789917},
#   {'label': 'anger', 'score': 0.032190266996622086},
#   {'label': 'neutral', 'score': 0.012808579951524734},
#   {'label': 'sadness', 'score': 0.008756828494369984},
#   {'label': 'surprise', 'score': 0.008597834967076778},
#   {'label': 'disgust', 'score': 0.008431742899119854},
#   {'label': 'joy', 'score': 0.0010455762967467308}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104149468243122},
#   {'label': 'disgust', 'score': 0.00648059556260705},
#   {'label': 'fear', 'score': 0.005393995437771082},
#   {'label': 'surprise', 'score': 0.0022869398817420006},
#   {'label': 'anger', 'score': 0.0018428885377943516},
#   {'label': 'joy', 'score': 0.0017338780453428626}],
#  [{'label': 'joy', 'score': 0.9327981472015381},
#   {'label': 'disgust', 'score': 0.03771703690290451},
#   {'label': 'neutral', 'score': 0.01589183323085308},
#   {'label': 'sadness', 'score': 0.006444488186389208},
#   {'label': 'anger', 'score': 0.005024972837418318},
#   {'label': 'surprise', 'score': 0.00158120587002486},
#   {'label': 'fear', 'score': 0.0005423062248155475}],
#  [{'label': 'joy', 'score': 0.6528705954551697},
#   {'label': 'neutral', 'score': 0.2542745769023895},
#   {'label': 'surprise', 'score': 0.06808319687843323},
#   {'label': 'sadness', 'score': 0.009909011423587799},
#   {'label': 'disgust', 'score': 0.006512208376079798},
#   {'label': 'anger', 'score': 0.004821314476430416},
#   {'label': 'fear', 'score': 0.003529018023982644}],
#  [{'label': 'neutral', 'score': 0.5494769811630249},
#   {'label': 'sadness', 'score': 0.11169016361236572},
#   {'label': 'disgust', 'score': 0.10400663316249847},
#   {'label': 'surprise', 'score': 0.07876548171043396},
#   {'label': 'anger', 'score': 0.06413359194993973},
#   {'label': 'fear', 'score': 0.0513627715408802},
#   {'label': 'joy', 'score': 0.0405643954873085}]]

# %%
sorted(predictions[0], key=lambda x: x["label"])
# Out:
# [{'label': 'anger', 'score': 0.009156350046396255},
#  {'label': 'disgust', 'score': 0.002628474496304989},
#  {'label': 'fear', 'score': 0.06816212087869644},
#  {'label': 'joy', 'score': 0.0479423888027668},
#  {'label': 'neutral', 'score': 0.14038564264774323},
#  {'label': 'sadness', 'score': 0.0021221598144620657},
#  {'label': 'surprise', 'score': 0.7296028733253479}]

# %%
import numpy as np

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
    per_emotion_scores = {label: [] for label in emotion_labels}
    for prediction in predictions:
        sorted_predictions = sorted(prediction, key=lambda x: x["label"])
        for index, label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_predictions[index]["score"])
    return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])

# %%
emotion_scores
# Out:
# {'anger': [np.float64(0.06413359194993973),
#   np.float64(0.6126173734664917),
#   np.float64(0.06413359194993973),
#   np.float64(0.35148340463638306),
#   np.float64(0.0814121812582016),
#   np.float64(0.2322247475385666),
#   np.float64(0.5381841063499451),
#   np.float64(0.06413359194993973),
#   np.float64(0.3006701171398163),
#   np.float64(0.06413359194993973)],
#  'disgust': [np.float64(0.273591011762619),
#   np.float64(0.34828588366508484),
#   np.float64(0.10400663316249847),
#   np.float64(0.15072235465049744),
#   np.float64(0.18449512124061584),
#   np.float64(0.7271748781204224),
#   np.float64(0.15585488080978394),
#   np.float64(0.10400663316249847),
#   np.float64(0.2794818580150604),
#   np.float64(0.17792631685733795)],
#  'fear': [np.float64(0.9281691312789917),
#   np.float64(0.942527711391449),
#   np.float64(0.9723208546638489),
#   np.float64(0.36070728302001953),
#   np.float64(0.09504321217536926),
#   np.float64(0.0513627715408802),
#   np.float64(0.7474280595779419),
#   np.float64(0.4044966697692871),
#   np.float64(0.9155242443084717),
#   np.float64(0.0513627715408802)],
#  'joy': [np.float64(0.9327981472015381),
#   np.float64(0.7044214606285095),
#   np.float64(0.7672366499900818),
#   np.float64(0.251880943775177),
#   np.float64(0.0405643954873085),
#   np.float64(0.043375786393880844),
#   np.float64(0.8725652694702148),
#   np.float64(0.0405643954873085),
#   np.float64(0.0405643954873085),
#   np.float64(0.0405643954873085)],
#  'sadness': [np.float64(0.6462168097496033),
#   np.float64(0.887939453125),
#   np.float64(0.5494769811630249),
#   np.float64(0.7326860427856445),
#   np.float64(0.8843889832496643),
#   np.float64(0.6213931441307068),
#   np.float64(0.7121940851211548),
#   np.float64(0.5494769811630249),
#   np.float64(0.8402894735336304),
#   np.float64(0.8603722453117371)],
#  'surprise': [np.float64(0.9671575427055359),
#   np.float64(0.11169016361236572),
#   np.float64(0.11169016361236572),
#   np.float64(0.11169016361236572),
#   np.float64(0.47588130831718445),
#   np.float64(0.11169016361236572),
#   np.float64(0.40799832344055176),
#   np.float64(0.820281982421875),
#   np.float64(0.35445985198020935),
#   np.float64(0.11169016361236572)],
#  'neutral': [np.float64(0.7296028733253479),
#   np.float64(0.25254544615745544),
#   np.float64(0.07876548171043396),
#   np.float64(0.07876548171043396),
#   np.float64(0.07876548171043396),
#   np.float64(0.27190229296684265),
#   np.float64(0.07876548171043396),
#   np.float64(0.2344876527786255),
#   np.float64(0.1356145143508911),
#   np.float64(0.07876548171043396)]}

# %%
from tqdm import tqdm

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 5197/5197 [03:12<00:00, 27.04it/s]

# %%
emotions_df = pd.DataFrame(emotion_scores)
emotions_df["isbn13"] = isbn

# %%
emotions_df
# Out:
#          anger   disgust      fear       joy   sadness  surprise   neutral  \
# 0     0.064134  0.273591  0.928169  0.932798  0.646217  0.967158  0.729603
# 1     0.612617  0.348286  0.942528  0.704421  0.887939  0.111690  0.252545
# 2     0.064134  0.104007  0.972321  0.767237  0.549477  0.111690  0.078765
# 3     0.351483  0.150722  0.360707  0.251881  0.732686  0.111690  0.078765
# 4     0.081412  0.184495  0.095043  0.040564  0.884389  0.475881  0.078765
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148208  0.030642  0.919165  0.255171  0.853722  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400262  0.883198  0.111690  0.227765
# 5194  0.009997  0.009929  0.339217  0.947779  0.375756  0.066685  0.057625
# 5195  0.064134  0.104007  0.459267  0.759455  0.951104  0.368110  0.078765
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078765
#
#              isbn13
# 0     9780002005883
# 1     9780002261982
# 2     9780006178736
# 3     9780006280897
# 4     9780006280934
# ...             ...
# 5192  9788172235222
# 5193  9788173031014
# 5194  9788179921623
# 5195  9788185300535
# 5196  9789027712059
#
# [5197 rows x 8 columns]

# %%
books = pd.merge(books, emotions_df, on = "isbn13")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ...  \
# 0               3.85      247.0  ...
# 1               3.83      241.0  ...
# 2               3.93      512.0  ...
# 3               4.15      170.0  ...
# 4               4.09      176.0  ...
# ...              ...        ...  ...
# 5192            2.93      324.0  ...
# 5193            3.70      175.0  ...
# 5194            3.82      198.0  ...
# 5195            4.51      531.0  ...
# 5196            0.00      210.0  ...
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories  \
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...           Fiction
# 5193  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5194  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
#          anger   disgust      fear       joy   sadness  surprise   neutral
# 0     0.064134  0.273591  0.928169  0.932798  0.646217  0.967158  0.729603
# 1     0.612617  0.348286  0.942528  0.704421  0.887939  0.111690  0.252545
# 2     0.064134  0.104007  0.972321  0.767237  0.549477  0.111690  0.078765
# 3     0.351483  0.150722  0.360707  0.251881  0.732686  0.111690  0.078765
# 4     0.081412  0.184495  0.095043  0.040564  0.884389  0.475881  0.078765
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148208  0.030642  0.919165  0.255171  0.853722  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400262  0.883198  0.111690  0.227765
# 5194  0.009997  0.009929  0.339217  0.947779  0.375756  0.066685  0.057625
# 5195  0.064134  0.104007  0.459267  0.759455  0.951104  0.368110  0.078765
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078765
#
# [5197 rows x 21 columns]

# %%
books.to_csv("books_with_emotions.csv", index = False)
